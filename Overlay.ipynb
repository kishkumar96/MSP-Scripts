# %%
import geopandas as gpd
"""
This script performs a biodiversity assessment by analyzing the intersection between fishing zones and various biodiversity layers.
It calculates the total area and percentage of each biodiversity layer within each fishing zone.
The script generates summary reports in CSV format and a PDF report with overall and category-specific statistics.
Additionally, it creates bar charts to visualize the percentage distribution of biodiversity within zones and the percentage of each zone occupied by each biodiversity layer.
Parameters:
    None
Returns:
    None
"""
import matplotlib.pyplot as plt
from matplotlib.ticker import ScalarFormatter
import pandas as pd
from reportlab.lib.pagesizes import A3
from reportlab.platypus import SimpleDocTemplate, Table, TableStyle, Paragraph, Spacer, Image
from reportlab.lib.styles import getSampleStyleSheet
import os
import logging
import numpy as np
from reportlab.lib import colors

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# Define paths to grouped layers and their corresponding category column names
grouped_layers = {
    'Abyssal Classification': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Missed\Palau_Seafloor_Abyssal_Classification.shp', 'category_column': 'Class'},
    'Basins': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Palau__Seafloor_Basins.shp', 'category_column': 'Type'},
    'Bridges': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Palau__Seafloor_Bridges.shp', 'category_column': None},
    'Canyons': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Missed\Palau_Seafloor_Canyons.shp', 'category_column': 'type'},
    'Escarpments': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Missed\Palau___Seafloor_Escarpments.shp', 'category_column': None},
    'Ridges': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Palau__Seafloor_Ridges.shp', 'category_column': None},
    'Shelf Classification': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Missed\Palau_Seafloor_Shelf_Classification.shp', 'category_column': 'Class'},
    'Slopes': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Palau__Seafloor_Slope.shp', 'category_column': None},
    'Trenches': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Palau__Seafloor_Trenches.shp', 'category_column': None},
    'Hadal': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Palau__Seafloor_Hadal0.shp', 'category_column': None},
    'Rift Valleys': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Palau__Seafloor_Rift_valleys.shp', 'category_column': None},
    'Seamounts': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Palau__Seafloor_Seamounts.shp', 'category_column': None},
    'Bioregions': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Missed\Palau_SWP_Deepwater_Bioregions_technical_analysis_final_28.03.18.shp', 'category_column': 'Draft name'},
    'Spreading Ridges': {'path': r'C:\Users\kishank\Downloads\MSP Datasets\Workingfolder\Reprojected\Clipped\Palau__Seafloor_Spreading_ridges0.shp', 'category_column': None},
}

fishing_zone_layer_path = r"C:\Users\kishank\Downloads\Zones_Palau.shp"

# Load fishing zone layer
logging.info("Loading fishing zone layer")
fishing_zone_layer = gpd.read_file(fishing_zone_layer_path).to_crs(epsg=3857)  # Reproject to a suitable projected CRS

# Ensure output directory exists
output_directory = r'C:\Users\kishank\Downloads\MSP Datasets\Reprojected\Clipped\Missed4\intersect_outputs'
os.makedirs(output_directory, exist_ok=True)

# Iterate through each unique zone
for zone in fishing_zone_layer['Zone'].unique():
    logging.info(f"Processing Zone: {zone}")
    zone_layer = fishing_zone_layer[fishing_zone_layer['Zone'] == zone]
    zone_name = f"{zone}"

    # Calculate the total area of the fishing zone
    fishing_zone_total_area = zone_layer['geometry'].area.sum() / 1e6  # Convert to square kilometers

    # Initialize DataFrames for summary reports
    overall_summary = []
    category_summary = []

    total_layers = len(grouped_layers)
    processed_layers = 0

    for group, layer_info in grouped_layers.items():
        processed_layers += 1
        progress = (processed_layers / total_layers) * 100
        logging.info(f"Processing {group} ({processed_layers}/{total_layers}) - {progress:.2f}% completed")

        layer_path = layer_info['path']
        category_column = layer_info['category_column']

        biodiversity_layer = gpd.read_file(layer_path).to_crs(epsg=3857)  # Reproject to a suitable projected CRS
        if biodiversity_layer.empty:
            logging.error(f"Failed to load {layer_path}")
            continue

        # Perform intersection
        intersected_layer = gpd.overlay(biodiversity_layer, zone_layer, how='intersection')

        # Calculate areas within zone
        intersected_layer['area_zone'] = intersected_layer['geometry'].area / 1e6  # Convert to square kilometers
        biodiversity_layer['total_area'] = biodiversity_layer['geometry'].area / 1e6  # Convert to square kilometers

        # Save intersected spatial files
        intersected_layer_path = os.path.join(output_directory, f'{group}_{zone_name}_intersected.shp')
        intersected_layer.to_file(intersected_layer_path)

        # Summarize overall statistics
        total_area = biodiversity_layer['total_area'].sum()
        area_within_zone = intersected_layer['area_zone'].sum()
        percentage_within_zone = (area_within_zone / total_area) * 100 if total_area > 0 else 0
        percentage_of_fishing_zone = (area_within_zone / fishing_zone_total_area) * 100 if fishing_zone_total_area > 0 else 0
        overall_summary.append([group, total_area, area_within_zone, percentage_within_zone, percentage_of_fishing_zone])

        if category_column and category_column in biodiversity_layer.columns:
            # Summarize category-specific statistics
            for category in biodiversity_layer[category_column].unique():
                category_biodiversity = biodiversity_layer[biodiversity_layer[category_column] == category]
                category_intersected = intersected_layer[intersected_layer[category_column] == category]

                category_total_area = category_biodiversity['total_area'].sum()
                category_area_within_zone = category_intersected['area_zone'].sum()
                category_percentage_within_zone = (category_area_within_zone / category_total_area) * 100 if category_total_area > 0 else 0
                category_percentage_of_fishing_zone = (category_area_within_zone / fishing_zone_total_area) * 100 if fishing_zone_total_area > 0 else 0
                category_summary.append([group, category, category_total_area, category_area_within_zone, category_percentage_within_zone, category_percentage_of_fishing_zone])

                # Generate bar chart
                categories_list = biodiversity_layer[category_column].unique()
                total_areas = [biodiversity_layer[biodiversity_layer[category_column] == cat]['total_area'].sum() for cat in categories_list]
                within_zone_areas = [intersected_layer[intersected_layer[category_column] == cat]['area_zone'].sum() for cat in categories_list]
                total_areas_percentage = [total_area / sum(total_areas) * 100 for total_area in total_areas]
                within_zone_areas_percentage = [within_zone_area / sum(within_zone_areas) * 100 for within_zone_area in within_zone_areas]

                plt.figure(figsize=(15, 8))  # Adjusted figure size for better readability
                plt.bar(categories_list, total_areas_percentage, label='Total Area Percentage', alpha=0.6, color='b')
                plt.bar(categories_list, within_zone_areas_percentage, label='Area within Zones Percentage', alpha=0.6, color='orange')
                plt.xlabel('Category')
                plt.ylabel('Percentage (%)')
                plt.title(f'Percentage Distribution for {group}')
                plt.gca().yaxis.set_major_formatter(ScalarFormatter(useOffset=False))  # Disable scientific notation
                if group == 'Bioregions':
                    plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for bioregions to avoid overlap
                else:
                    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
                plt.legend()
                plt.tight_layout()  # Adjust layout to prevent label cutoff
                plt.savefig(os.path.join(output_directory, f'{group}_{zone_name}_percentage_distribution.png'))
                plt.close()

                # Generate bar chart for percentage of fishing zone
                plt.figure(figsize=(15, 8))  # Adjusted figure size for better readability
                plt.bar(categories_list, [within_zone / fishing_zone_total_area * 100 for within_zone in within_zone_areas], label='Percentage of Zone', alpha=0.6, color='g')
                plt.xlabel('Category')
                plt.ylabel('Percentage of Zone (%)')
                plt.title(f'Percentage of Zone Occupied by {group}')
                plt.gca().yaxis.set_major_formatter(ScalarFormatter(useOffset=False))  # Disable scientific notation
                if group == 'Bioregions':
                    plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for bioregions to avoid overlap
                else:
                    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
                plt.legend()
                plt.tight_layout()  # Adjust layout to prevent label cutoff
                plt.savefig(os.path.join(output_directory, f'{group}_{zone_name}_zone_percentage.png'))
                plt.close()
        elif category_column:
            logging.error(f"Category column '{category_column}' does not exist in {layer_path}")

    # Create summary DataFrames
    overall_summary_df = pd.DataFrame(overall_summary, columns=['Biodiversity Layer', 'Total Area (sq.km)', 'Area within Zone (sq.km)', 'Percentage within Zone (%)', 'Percentage of Zone (%)'])
    category_summary_df = pd.DataFrame(category_summary, columns=['Layer', 'Category', 'Total Area (sq.km)', 'Area within Zone (sq.km)', 'Percentage within Zone (%)', 'Percentage of Zone (%)'])

    # Format data to avoid scientific notation
    pd.options.display.float_format = '{:.6f}'.format

    # Save summaries to CSV
    overall_summary_df.to_csv(os.path.join(output_directory, f'overall_summary_{zone_name}.csv'), index=False)
    category_summary_df.to_csv(os.path.join(output_directory, f'category_summary_{zone_name}.csv'), index=False)

    # Validate calculations
    for group, layer_info in grouped_layers.items():
        layer_path = layer_info['path']
        category_column = layer_info['category_column']

        biodiversity_layer = gpd.read_file(layer_path).to_crs(epsg=3857)
        intersected_layer = gpd.read_file(os.path.join(output_directory, f'{group}_{zone_name}_intersected.shp'))

        calculated_area_within_zone = intersected_layer['geometry'].area.sum() / 1e6
        summary_area_within_zone = category_summary_df[category_summary_df['Layer'] == group]['Area within Zone (sq.km)'].sum()

        if not np.isclose(calculated_area_within_zone, summary_area_within_zone, rtol=1e-5):
            logging.error(f"Validation error for {group}: Calculated area within zone ({calculated_area_within_zone}) does not match summary area ({summary_area_within_zone})")

    # PDF report generation
    logging.info("Generating PDF report")
    report_path = os.path.join(output_directory, f'Biodiversity_Assessment_Report_{zone_name}.pdf')
    doc = SimpleDocTemplate(report_path, pagesize=A3, rightMargin=30, leftMargin=30, topMargin=30, bottomMargin=18)

    elements = []
    styles = getSampleStyleSheet()

    # Title
    title = Paragraph(f"Biodiversity Assessment Report - {zone_name}", styles['Title'])
    elements.append(title)
    elements.append(Spacer(1, 12))

    # Overall Summary Table
    overall_summary_title = Paragraph("Overall Summary", styles['Heading2'])
    elements.append(overall_summary_title)
    overall_data = [overall_summary_df.columns.tolist()] + overall_summary_df.values.tolist()
    overall_table = Table(overall_data, repeatRows=1)
    overall_table.setStyle(TableStyle([
        ('BACKGROUND', (0, 0), (-1, 0), colors.grey),
        ('TEXTCOLOR', (0, 0), (-1, 0), colors.whitesmoke),
        ('ALIGN', (0, 0), (-1, -1), 'CENTER'),
        ('FONTNAME', (0, 0), (-1, 0), 'Helvetica-Bold'),
        ('FONTSIZE', (0, 0), (-1, -1), 8),
        ('BOTTOMPADDING', (0, 0), (-1, 0), 12),
        ('BACKGROUND', (0, 1), (-1, -1), colors.beige),
        ('GRID', (0, 0), (-1, -1), 1, colors.black),
    ]))
    elements.append(overall_table)
    elements.append(Spacer(1, 12))

    # Category Summary Table
    category_summary_title = Paragraph("Category Summary", styles['Heading2'])
    elements.append(category_summary_title)
    category_data = [category_summary_df.columns.tolist()] + category_summary_df.values.tolist()

    # Calculate column widths based on the number of columns
    num_cols = len(category_summary_df.columns)
    page_width = A3[0] - doc.leftMargin - doc.rightMargin
    col_width = page_width / num_cols

    category_table = Table(category_data, colWidths=[col_width] * num_cols, repeatRows=1)
    category_table.setStyle(TableStyle([
        ('BACKGROUND', (0, 0), (-1, 0), colors.grey),
        ('TEXTCOLOR', (0, 0), (-1, 0), colors.whitesmoke),
        ('ALIGN', (0, 0), (-1, -1), 'CENTER'),
        ('FONTNAME', (0, 0), (-1, 0), 'Helvetica-Bold'),
        ('FONTSIZE', (0, 0), (-1, -1), 6),
        ('BOTTOMPADDING', (0, 0), (-1, 0), 12),
        ('BACKGROUND', (0, 1), (-1, -1), colors.beige),
        ('GRID', (0, 0), (-1, -1), 1, colors.black),
        ('LEFTPADDING', (0, 0), (-1, -1), 3),
        ('RIGHTPADDING', (0, 0), (-1, -1), 3),
    ]))
    elements.append(category_table)
    elements.append(Spacer(1, 12))

    # Add images
    for group in grouped_layers.keys():
        image_path = os.path.join(output_directory, f'{group}_{zone_name}_percentage_distribution.png')
        if os.path.exists(image_path):
            elements.append(Paragraph(f'Percentage Distribution for {group}', styles['Heading3']))
            elements.append(Image(image_path, width=700, height=400))
            elements.append(Spacer(1, 12))

        image_path = os.path.join(output_directory, f'{group}_{zone_name}__zone_percentage.png')
        if os.path.exists(image_path):
            elements.append(Paragraph(f'Percentage of Zone Occupied by {group}', styles['Heading3']))
            elements.append(Image(image_path, width=700, height=400))
            elements.append(Spacer(1, 12))

    doc.build(elements)
    logging.info(f"Processing for {zone_name} completed")

logging.info("All zones processed")
# Out:
# 2024-09-16 12:50:18,087 - INFO - Loading fishing zone layer
# 2024-09-16 12:50:18,183 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:18,200 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:18,241 - INFO - Processing Zone: New PNMS Footprint
# 2024-09-16 12:50:18,241 - INFO - Processing Abyssal Classification (1/14) - 7.14% completed
# 2024-09-16 12:50:18,250 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:18,274 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:19,248 - INFO - Processing Basins (2/14) - 14.29% completed
# 2024-09-16 12:50:19,265 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:19,289 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:20,273 - INFO - Processing Bridges (3/14) - 21.43% completed
# 2024-09-16 12:50:20,290 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:20,306 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# c:\Users\kishank\.conda\envs\firstenv\Lib\site-packages\geopandas\io\file.py:633: UserWarning: You are attempting to write an empty DataFrame to file. For some drivers, this operation may fail.
#   _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
# 2024-09-16 12:50:20,354 - INFO - Processing Canyons (4/14) - 28.57% completed
# 2024-09-16 12:50:20,362 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:20,379 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:20,967 - INFO - Processing Escarpments (5/14) - 35.71% completed
# 2024-09-16 12:50:20,975 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:20,991 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:21,102 - INFO - Processing Ridges (6/14) - 42.86% completed
# 2024-09-16 12:50:21,110 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:21,126 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:21,205 - INFO - Processing Shelf Classification (7/14) - 50.00% completed
# 2024-09-16 12:50:21,216 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:21,230 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# c:\Users\kishank\.conda\envs\firstenv\Lib\site-packages\geopandas\io\file.py:633: UserWarning: You are attempting to write an empty DataFrame to file. For some drivers, this operation may fail.
#   _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
# C:\Users\kishank\AppData\Local\Temp\ipykernel_30900\4272749007.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   within_zone_areas_percentage = [within_zone_area / sum(within_zone_areas) * 100 for within_zone_area in within_zone_areas]
# C:\Users\kishank\AppData\Local\Temp\ipykernel_30900\4272749007.py:118: RuntimeWarning: invalid value encountered in scalar divide
#   within_zone_areas_percentage = [within_zone_area / sum(within_zone_areas) * 100 for within_zone_area in within_zone_areas]
# 2024-09-16 12:50:21,842 - INFO - Processing Slopes (8/14) - 57.14% completed
# 2024-09-16 12:50:21,850 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:21,867 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# c:\Users\kishank\.conda\envs\firstenv\Lib\site-packages\geopandas\io\file.py:633: UserWarning: You are attempting to write an empty DataFrame to file. For some drivers, this operation may fail.
#   _to_file_fiona(df, filename, driver, schema, crs, mode, **kwargs)
# 2024-09-16 12:50:21,908 - INFO - Processing Trenches (9/14) - 64.29% completed
# 2024-09-16 12:50:21,916 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:21,932 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:21,976 - INFO - Processing Hadal (10/14) - 71.43% completed
# 2024-09-16 12:50:21,985 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:22,001 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:22,058 - INFO - Processing Rift Valleys (11/14) - 78.57% completed
# 2024-09-16 12:50:22,066 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:22,082 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:22,126 - INFO - Processing Seamounts (12/14) - 85.71% completed
# 2024-09-16 12:50:22,142 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:22,160 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:22,231 - INFO - Processing Bioregions (13/14) - 92.86% completed
# 2024-09-16 12:50:22,251 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:22,269 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:22,350 - WARNING - Value 88277549797.1999969 of field Shape_Area of feature 0 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,350 - WARNING - Value 22829822950.3915596 of field total_area of feature 0 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,359 - WARNING - Value 64204444638.9000015 of field Shape_Area of feature 1 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,359 - WARNING - Value 5403947754.90234375 of field total_area of feature 1 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,359 - WARNING - Value 286986691183 of field Shape_Area of feature 2 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,359 - WARNING - Value 77621423647.247818 of field total_area of feature 2 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,359 - WARNING - Value 274837960295 of field Shape_Area of feature 3 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,359 - WARNING - Value 45400634643.5404892 of field total_area of feature 3 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,359 - WARNING - Value 96664726652.3999939 of field Shape_Area of feature 4 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,359 - WARNING - Value 27892101434.964798 of field total_area of feature 4 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,367 - WARNING - Value 606629929288 of field Shape_Area of feature 5 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,367 - WARNING - Value 25327592279.9973946 of field total_area of feature 5 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,367 - WARNING - Value 228230864415 of field Shape_Area of feature 6 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,367 - WARNING - Value 98909752382.4179535 of field total_area of feature 6 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,367 - WARNING - Value 114061798255 of field Shape_Area of feature 7 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,367 - WARNING - Value 8951230428.88821793 of field total_area of feature 7 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,367 - WARNING - Value 189906236760.000031 of field Shape_Area of feature 8 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,367 - WARNING - Value 55409304896.0862961 of field total_area of feature 8 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,375 - WARNING - Value 209824143890 of field Shape_Area of feature 9 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,375 - WARNING - Value 151899016218.257629 of field total_area of feature 9 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,375 - WARNING - Value 69472878156.5 of field Shape_Area of feature 10 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,375 - WARNING - Value 3007204447.99158096 of field total_area of feature 10 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,375 - WARNING - Value 83826906400.6000061 of field Shape_Area of feature 11 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,375 - WARNING - Value 6299340816.78079796 of field total_area of feature 11 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,375 - WARNING - Value 79083019080.8999939 of field Shape_Area of feature 12 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,375 - WARNING - Value 315447644.814266205 of field total_area of feature 12 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,383 - WARNING - Value 79157280792.5 of field Shape_Area of feature 13 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,383 - WARNING - Value 6713842562.67133141 of field total_area of feature 13 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,383 - WARNING - Value 38218398342.0999985 of field Shape_Area of feature 14 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,383 - WARNING - Value 34497356361.7527618 of field total_area of feature 14 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,383 - WARNING - Value 13909688981.5 of field Shape_Area of feature 15 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:22,383 - WARNING - Value 13909688981.4646263 of field total_area of feature 15 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:31,492 - INFO - Processing Spreading Ridges (14/14) - 100.00% completed
# 2024-09-16 12:50:31,508 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:31,524 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:31,581 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:31,598 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:31,657 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:31,673 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:31,697 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:31,705 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:31,891 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:31,916 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:31,964 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:31,986 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,010 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,027 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,040 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,058 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,099 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,108 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,125 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,141 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,196 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,212 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,220 - ERROR - Validation error for Escarpments: Calculated area within zone (49024.70405508326) does not match summary area (0.0)
# 2024-09-16 12:50:32,237 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,254 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,320 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,336 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,344 - ERROR - Validation error for Ridges: Calculated area within zone (30627.00156489523) does not match summary area (0.0)
# 2024-09-16 12:50:32,352 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,369 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,394 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,407 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,415 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,431 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,456 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,472 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,480 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,496 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,544 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,561 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,561 - ERROR - Validation error for Trenches: Calculated area within zone (2106.309928206121) does not match summary area (0.0)
# 2024-09-16 12:50:32,569 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,594 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,626 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,643 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,643 - ERROR - Validation error for Hadal: Calculated area within zone (483.4748578370492) does not match summary area (0.0)
# 2024-09-16 12:50:32,651 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,667 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,708 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,724 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,724 - ERROR - Validation error for Rift Valleys: Calculated area within zone (3476.819935039716) does not match summary area (0.0)
# 2024-09-16 12:50:32,740 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,753 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,794 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,802 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,810 - ERROR - Validation error for Seamounts: Calculated area within zone (8923.983477915128) does not match summary area (0.0)
# 2024-09-16 12:50:32,818 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,842 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,907 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,923 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,940 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,948 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:32,996 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:33,012 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:33,020 - ERROR - Validation error for Spreading Ridges: Calculated area within zone (23733.01834563829) does not match summary area (0.0)
# 2024-09-16 12:50:33,020 - INFO - Generating PDF report
# 2024-09-16 12:50:33,354 - INFO - Processing for New PNMS Footprint completed
# 2024-09-16 12:50:33,354 - INFO - Processing Zone: Artisanal Fishing Zone
# 2024-09-16 12:50:33,354 - INFO - Processing Abyssal Classification (1/14) - 7.14% completed
# 2024-09-16 12:50:33,378 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:33,397 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:34,231 - INFO - Processing Basins (2/14) - 14.29% completed
# 2024-09-16 12:50:34,247 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:34,261 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:35,148 - INFO - Processing Bridges (3/14) - 21.43% completed
# 2024-09-16 12:50:35,156 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:35,172 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:35,208 - INFO - Processing Canyons (4/14) - 28.57% completed
# 2024-09-16 12:50:35,216 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:35,237 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:35,773 - INFO - Processing Escarpments (5/14) - 35.71% completed
# 2024-09-16 12:50:35,780 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:35,797 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:35,902 - INFO - Processing Ridges (6/14) - 42.86% completed
# 2024-09-16 12:50:35,910 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:35,926 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:35,995 - INFO - Processing Shelf Classification (7/14) - 50.00% completed
# 2024-09-16 12:50:36,003 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,019 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,539 - INFO - Processing Slopes (8/14) - 57.14% completed
# 2024-09-16 12:50:36,547 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,563 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,612 - INFO - Processing Trenches (9/14) - 64.29% completed
# 2024-09-16 12:50:36,620 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,645 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,694 - INFO - Processing Hadal (10/14) - 71.43% completed
# 2024-09-16 12:50:36,702 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,718 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,758 - INFO - Processing Rift Valleys (11/14) - 78.57% completed
# 2024-09-16 12:50:36,766 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,783 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,823 - INFO - Processing Seamounts (12/14) - 85.71% completed
# 2024-09-16 12:50:36,831 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,855 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,905 - INFO - Processing Bioregions (13/14) - 92.86% completed
# 2024-09-16 12:50:36,913 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,929 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:36,986 - WARNING - Value 286986691183 of field Shape_Area of feature 0 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:36,986 - WARNING - Value 77621423647.247818 of field total_area of feature 0 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:36,994 - WARNING - Value 96664726652.3999939 of field Shape_Area of feature 1 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:36,995 - WARNING - Value 27892101434.964798 of field total_area of feature 1 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:36,995 - WARNING - Value 96664726652.3999939 of field Shape_Area of feature 2 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:36,995 - WARNING - Value 27892101434.964798 of field total_area of feature 2 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:36,995 - WARNING - Value 606629929288 of field Shape_Area of feature 3 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:36,995 - WARNING - Value 25327592279.9973946 of field total_area of feature 3 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:36,995 - WARNING - Value 228230864415 of field Shape_Area of feature 4 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:36,995 - WARNING - Value 98909752382.4179535 of field total_area of feature 4 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:36,995 - WARNING - Value 228230864415 of field Shape_Area of feature 5 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,003 - WARNING - Value 98909752382.4179535 of field total_area of feature 5 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,003 - WARNING - Value 189906236760.000031 of field Shape_Area of feature 6 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,003 - WARNING - Value 55409304896.0862961 of field total_area of feature 6 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,003 - WARNING - Value 209824143890 of field Shape_Area of feature 7 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,003 - WARNING - Value 151899016218.257629 of field total_area of feature 7 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,003 - WARNING - Value 209824143890 of field Shape_Area of feature 8 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,003 - WARNING - Value 151899016218.257629 of field total_area of feature 8 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,011 - WARNING - Value 50092378343 of field Shape_Area of feature 9 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,011 - WARNING - Value 19880247192.5935936 of field total_area of feature 9 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,011 - WARNING - Value 38218398342.0999985 of field Shape_Area of feature 10 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,011 - WARNING - Value 34497356361.7527618 of field total_area of feature 10 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,011 - WARNING - Value 38218398342.0999985 of field Shape_Area of feature 11 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,011 - WARNING - Value 34497356361.7527618 of field total_area of feature 11 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,011 - WARNING - Value 13909688981.5 of field Shape_Area of feature 12 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:37,011 - WARNING - Value 13909688981.4646263 of field total_area of feature 12 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:50:45,967 - INFO - Processing Spreading Ridges (14/14) - 100.00% completed
# 2024-09-16 12:50:45,975 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:45,991 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,052 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,066 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,115 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,132 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,162 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,177 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,269 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,277 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,301 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,318 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,351 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,367 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,367 - ERROR - Validation error for Bridges: Calculated area within zone (25.26759339584999) does not match summary area (0.0)
# 2024-09-16 12:50:46,375 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,391 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,437 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,445 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,462 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,478 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,536 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,553 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,570 - ERROR - Validation error for Escarpments: Calculated area within zone (43529.6066407502) does not match summary area (0.0)
# 2024-09-16 12:50:46,586 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,602 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,651 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,670 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,695 - ERROR - Validation error for Ridges: Calculated area within zone (21694.69847755118) does not match summary area (0.0)
# 2024-09-16 12:50:46,703 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,723 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,761 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,769 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,785 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,802 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,843 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,860 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,868 - ERROR - Validation error for Slopes: Calculated area within zone (1008.5235003097466) does not match summary area (0.0)
# 2024-09-16 12:50:46,876 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,894 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,926 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,942 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,950 - ERROR - Validation error for Trenches: Calculated area within zone (7504.014651995164) does not match summary area (0.0)
# 2024-09-16 12:50:46,958 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:46,974 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:47,015 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:47,031 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:50:47,039 - ERROR - Validation error for Hadal: Calculated area within zone (4051.8632347364464) does not match summary area (0.0)
# 2024-09-16 12:50:47,048 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# ...
# 2024-09-16 12:51:07,321 - WARNING - Value 189906236760.000031 of field Shape_Area of feature 8 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,321 - WARNING - Value 55409304896.0862961 of field total_area of feature 8 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,329 - WARNING - Value 209824143890 of field Shape_Area of feature 9 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,329 - WARNING - Value 151899016218.257629 of field total_area of feature 9 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,329 - WARNING - Value 69472878156.5 of field Shape_Area of feature 10 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,338 - WARNING - Value 3007204447.99158096 of field total_area of feature 10 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,338 - WARNING - Value 95533883246.1000061 of field Shape_Area of feature 11 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,338 - WARNING - Value 965621655.560749054 of field total_area of feature 11 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,338 - WARNING - Value 83826906400.6000061 of field Shape_Area of feature 12 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,347 - WARNING - Value 6299340816.78079796 of field total_area of feature 12 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,347 - WARNING - Value 50092378343 of field Shape_Area of feature 13 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,347 - WARNING - Value 19880247192.5935936 of field total_area of feature 13 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,347 - WARNING - Value 79157280792.5 of field Shape_Area of feature 14 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,347 - WARNING - Value 6713842562.67133141 of field total_area of feature 14 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,347 - WARNING - Value 38218398342.0999985 of field Shape_Area of feature 15 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:07,355 - WARNING - Value 34497356361.7527618 of field total_area of feature 15 not successfully written. Possibly due to too larger number with respect to field width
# 2024-09-16 12:51:17,613 - INFO - Processing Spreading Ridges (14/14) - 100.00% completed
# 2024-09-16 12:51:17,629 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,646 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,704 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,719 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,759 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,776 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,800 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,816 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,885 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,893 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,917 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,933 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,949 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,966 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,974 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:17,990 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,030 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,046 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,054 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,070 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,143 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,155 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,172 - ERROR - Validation error for Escarpments: Calculated area within zone (27480.083395317542) does not match summary area (0.0)
# 2024-09-16 12:51:18,180 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,196 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,236 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,252 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,260 - ERROR - Validation error for Ridges: Calculated area within zone (16365.965697994905) does not match summary area (0.0)
# 2024-09-16 12:51:18,276 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,292 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,310 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,326 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,342 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,358 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,374 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,390 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,406 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,430 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,447 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,458 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,474 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,490 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,514 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,531 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,539 - ERROR - Validation error for Hadal: Calculated area within zone (9373.037728589976) does not match summary area (0.0)
# 2024-09-16 12:51:18,555 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,573 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,604 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,620 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,628 - ERROR - Validation error for Rift Valleys: Calculated area within zone (351.7302401318434) does not match summary area (0.0)
# 2024-09-16 12:51:18,642 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,654 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,719 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,735 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,743 - ERROR - Validation error for Seamounts: Calculated area within zone (19645.775685948684) does not match summary area (0.0)
# 2024-09-16 12:51:18,751 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,767 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,815 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,831 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,848 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,864 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,880 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,903 - ERROR - PROJ: proj_identify: C:\OSGeo4W\share\proj\proj.db contains DATABASE.LAYOUT.VERSION.MINOR = 1 whereas a number >= 2 is expected. It comes from another PROJ installation.
# 2024-09-16 12:51:18,903 - ERROR - Validation error for Spreading Ridges: Calculated area within zone (4636.726648303329) does not match summary area (0.0)
# 2024-09-16 12:51:18,903 - INFO - Generating PDF report
# 2024-09-16 12:51:19,238 - INFO - Processing for Offshore Fishing Zone completed
# 2024-09-16 12:51:19,246 - INFO - All zones processed
